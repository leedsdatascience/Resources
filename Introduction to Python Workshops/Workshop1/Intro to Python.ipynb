# %% [markdown]
# <img style="float: left;margin:0 10px 10px 0" src="Intro_to_Python\DSS_logo2.png" width=80>
#
# #  Introduction to Python: Workshop 1
#
# #### Content created by Francesca Pontin [francescapontin.com](http://francescapontin.com/teaching_materials.html)

# %% [markdown]
# <img src="Intro_to_Python\python_meme.png" width=500>
#
# Source: [Reddit](https://www.reddit.com/r/ProgrammerHumor/comments/9c55gd/python/)

# %% [markdown]
# Welcome to coding in Python! These three workshops are designed to introduce you to the basics of coding in Python and then get you to apply your new found coding skills to carry out some data analytics!
# This workshop is written in a Jupyter Notebook. A Jupyter Notebook ["is an open source web application that you can use to create and share documents that contain live code, equations, visualizations, and text"](https://realpython.com/jupyter-notebook-introduction/). A Jupyter Notebook is made up of cells (the grey boxes). These cells can be text (known as markdown), code or visulisations/images, to name a few.
# To select a cell click anywhere in the box and a large blue box will appear arround it. To edit a cell click in it twice and the surrounding box will turn green. <br>
# As shown bellow.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# During this workshop you will read through the Jupyter Notebok, running sections of code yourself to learn key data analysis skills. There will also be places to edit and write your own code within the notebook.
#
# #### <font color='orchid'>Instructions and tasks for you to complete are in purple</font>
#
# ### How to run a cell of code
# To run code select the cell you want to run (the blue box will appear arround the selected cell) and then EITHER:
#
# 1) type CTRL + ENTER on your key board
#
# OR
#
# 2) click "Run" on the Jupter Notebook the menu above
# <img src="Intro_to_Python\running_code.png" width=500>

# %% [markdown]
# ### How do I know if I have run the cell?
# If the cell has been run a number will appear in squared brackets by the cell e.g. <code>In [1]: or In [12]:</code>
#
# The numbering refers to the order in which you have run the cells
#
# An un-run cell has an empty set of squared brackets by the cell I.e. <code>In []:</code>

# %% [markdown]
# ### How do I add a new cell?
#
# To add a new cell select a cell (so it is surrounded by a blue box) and type 'b' to add a cell bellow or 'a' to add a cell above.
#
# To delete a cell select it and double tap 'd'.

# %% [markdown]
# # Hello World

# %% [markdown]
# In coding tradition the first thing we are going to program is to print the words "Hello World".
#
# The <code>print() </code> function prints the specified message to your screen
#
# The speech marks <code>" "</code> arround Hello World let python know you are typing text (also known as a string).
#
#  <font color='orchid'> <b>Run the code below</b></font>

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Basic maths

# %% [markdown]
# Lets do some basic maths
# <br><font color='orchid'> <b>Run the code below</b></font>

# %%
2+2
# Out:
# 4

# %% [markdown]
# If we print 2+2 we get the same thing
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
print(2+2)
# Out:
# 4

# %% [markdown]
# If we <code>print("2+2")</code> however we get the characters 2 + 2 as the speach marks tell Python we are typing text and not numerical characters
#
#
# <br> <font color='orchid'> <b>Run the code below</b></font> and see for yourself

# %%
print("2+2")
# Out:
# 2+2

# %% [markdown]
# We can also assign the sum 2+2 to a variable.
#
# In this case we have named the variable <font color='blue'>answer</font>. We can now type <font color='blue'>answer</font> instead of 2+2 every time.
#
# <br> <font color='orchid'> <b>To assign 2+2 to the variable answer run the code below</b></font>

# %%
answer = 2+2
print(answer)
# Out:
# 4

# %% [markdown]
# NOTE: <code>#</code> When a hashtag is added to a line of code the rest of that line is not treated as code.
# This can be used to add comments to your code so you know what it is doing (especially useful when you come back to it later on!)

# %%
# we can also add our created variable to a new equation
answer + 5
# Out:
# 9

# %% [markdown]
# # Importing Packages

# %% [markdown]
# Python has a lot of basic functionality built in e.g. the maths we have just done, but a lot of the time while doing data analysis you will require more than the basic funcitonality. This is when you need to import packages.
# If you have seen anyone elses code before you will note people tend to install all packages at the begining of their code.

# %% [markdown]
# To import a package use the statement <code>import</code> followed by the <code>package_name</code>.
#
# <br> <font color='orchid'> <b>Run the code below</b></font> to import the pandas package. <br>(nothing will appear in the cell but a number will appear in the squared brackets)

# %%
import pandas

# %% [markdown]
# ### The pandas package
# The pandas package allows us to easily create and handle dataframes, similar to Excel. Data is put into an easily readable format of columns and rows.
#
# It also allows us to read in data from a CSV file or excle file.
#
# When we use the package we refer to it for example <code>pandas.read_csv()</code>
#
# #### Note on abbreviating packages
# To save us having to type out pandas everytime we can abbreviate pandas to pd using the code bellow (<font color='orchid'> <b>Run the code below</b></font>).
#
# This is often done for commonly used packages to save time and redce the likelihod of typos while coding.
#
# So <code>pandas.read_csv()</code> becomes <code>pd.read_csv()</code>.

# %%
import pandas as pd

# %% [markdown]
# #### Now let's install some of the packages we will need for the rest of the workshop
# <font color='orchid'> <b>Run the code below</b></font>

# %%
# Import other required packages

# packages for visulising data
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # The data science process
#
# In this introduction to Python workshop we are going to follow the basic data science/ analysis process (Sarah introduced this process flow in our intro to data science talk earlier in the year). This week we will introduce you to some basic data manipualtion, data cleaning and visulisation skills in Python.In the second workshop we will look at some methods of data analysis and more complex visulisations.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Reading in data

# %% [markdown]
# For this workshop we will be using some data I have fabriacated about buying coffee (my favourite thing to do). Before we get started with any analysis we need to import the data.
#
# The data is originally in a CSV (comma seperated variable) format. To read the data into a dataframe we will use the pandas package introduced above, using the <code>pd.read_csv()</code> function.
#
# The <code>pd.read_csv()</code> function requires a 'filepath', i.e. we need to tell python where to find the data. To do this we put the filepath in speechmarks within the brackets of the function.
# I.e. <code>pd.read_csv("<font color='blue'>file_path</font>")</code>
#
# There is a <a href='#file_paths'>quick note about file paths</a> bellow if these are new to you
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee = pd.read_csv("Intro_to_Python/coffee_data.csv")

# %% [markdown]
# ##### So what have we done in the above code?
#
# We have told pandas to read in a csv file and provide the path to where the CSV file can be found; saved in a folder within my documents.
#
# We have also told pandas to assign the dataframe the name 'coffee'
# It is useful to have logical dataframe names  rather than df1, df2, etc. So you know what you are referring to when you come back to your code.

# %% [markdown]
# # Exploring the data

# %% [markdown]
# ### Data type

# %% [markdown]
# We can check that the coffee data has been stored in a dataframe by using the function <code>type()</code>
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
type(coffee)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Look at the dataframe

# %% [markdown]
# So what does the coffee dataframe look like?
# By typing coffee we can see the dataframe in full
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee
# Out:
#              coffee_name coffee_type coffee_shop  price  cake_deal  rating
# 0         nero_americano   americano        nero   2.40       True       4
# 1             nero_mocha       mocha        nero   2.60      False       5
# 2             nero_latte       latte        nero   2.50      False       3
# 3         nero_espresso    espresso         nero   2.00       True       4
# 4        nero_cappuccino  cappuccino        nero   2.50      False       4
# 5        nero_puppuccino  puppuccino        nero   2.70      False       1
# 6        costa_americano   americano       costa   2.75       True       3
# 7            costa_mocha       mocha       costa   3.00       True       4
# 8            costa_latte       latte       costa   2.90       True       4
# 9        costa_espresso    espresso        costa   1.80       True       2
# 10      costa_cappuccino  cappuccino       costa   3.00       True       4
# ...

# %% [markdown]
# With large dataframes it is easier to just look at the top few lines. To do this we type <code><font color='blue'>dataframe_name</font>.head()</code> which gives us the first 5 lines of the dataframe as well as the column headings.
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee.head()
# Out:
#        coffee_name coffee_type coffee_shop  price  cake_deal  rating
# 0   nero_americano   americano        nero    2.4       True       4
# 1       nero_mocha       mocha        nero    2.6      False       5
# 2       nero_latte       latte        nero    2.5      False       3
# 3   nero_espresso    espresso         nero    2.0       True       4
# 4  nero_cappuccino  cappuccino        nero    2.5      False       4

# %% [markdown]
# Alternatively we can use tail to see the last 5 lines of the table. Do the same thing but replace <code>.head()</code> with <code>.tail()</code>
# <br> <font color='orchid'> <b>Try this in the cell bellow.</b></font>

# %% [markdown]
# This is what you should see
# ![image.png](attachment:image.png)

# %% [markdown]
# # Data Types
#
# #### There are different types of data:
#
# <b>Objects:</b> also known as strings or written characters/text in plain english e.g. Hello World
#
# <b>Intergers:</b> Numeric characters e.g. 2
#
# <b>Floats:</b> Numeric characters with decimals e.g. 2.34534
#
# <b>Datetime:</b> Values that are either a date, time or both e.g. 2019-10-31 09:26:03.478039 (9:26 am on Halloween 2019)
#
# <b>Boolean:</b> True or False data type
# <br>
#
# Learn more about python data types using this realpython [online resource](https://realpython.com/python-data-types/)
# <br>
# <br>
# <br>
# We can check the data type of each column in a dataframe using the <code>.dtypes</code> funciton
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee.dtypes
# Out:
# coffee_name     object
# coffee_type     object
# coffee_shop     object
# price          float64
# cake_deal         bool
# rating           int64
# dtype: object

# %% [markdown]
# We can also explore the different columns and get some basic summary statisitcs by using the function <code>.describe()</code>
# <br>This is only possible for columns with a numeric (interger or float) data type.
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee.describe()
# Out:
#            price    rating
# count  24.000000  24.00000
# mean    3.129167   3.37500
# std     3.640441   1.13492
# min     0.800000   1.00000
# 25%     2.175000   3.00000
# 50%     2.500000   4.00000
# 75%     2.862500   4.00000
# max    20.000000   5.00000

# %% [markdown]
# ### Referring to a column in a dataframe
#
# If we want to sunamrise a single column of the dataframe we can also do that.
#
# There are several ways to refer to a column in a pandas dataframe.
#
# The easiest way is by putting the name of the column in square barckets and speech marks <code>[" "]</code> after the name of the dataframe.
# e.g. <code><font color='blue'>dataframe_name</font>["<font color='blue'>column_name</font>"].describe()

# %%
coffee['price'].describe()
# Out:
# count    24.000000
# mean      3.129167
# std       3.640441
# min       0.800000
# 25%       2.175000
# 50%       2.500000
# 75%       2.862500
# max      20.000000
# Name: price, dtype: float64

# %% [markdown]
# We can also just get one of the metrics from the <code>describe()</code> function e.g. <code>.mean()</code>, <code>.quantile(0.75)</code>, <code>.max()</code>

# %% [markdown]
# #### Mean

# %%
coffee['price'].mean()
# Out:
# 3.129166666666667

# %% [markdown]
# #### Median

# %%
coffee['price'].median()
# Out:
# 2.5

# %% [markdown]
# #### Quantile

# %%
# Get the 75% quantile
coffee['price'].quantile(0.75)
# Out:
# 2.8625000000000003

# %% [markdown]
# <br> <font color='orchid'> <b>Write your own code below to get the 25% quantile</b></font>

# %%
# Get the 25% quantile

# %% [markdown]
# #### Maximum and Minimum

# %%
# get the maximum coffee price
coffee['price'].max()
# Out:
# 20.0

# %% [markdown]
# <br> <font color='orchid'> <b>Write your own code below to get the cheapest coffee price</b></font>

# %%
# get the minimum coffee price

# %% [markdown]
# Looking at the result of <code>coffee['price'].max()</code> £20 seems a bit expensive for a coffee- lets have a look at all the coffee prices using the <code>print()</code> function.

# %%
list(coffee['price'])
# Out:
# [2.4,
#  2.6,
#  2.5,
#  2.0,
#  2.5,
#  2.7,
#  2.75,
#  3.0,
#  2.9,
#  1.8,
#  3.0,
#  2.5,
#  3.0,
#  2.7,
#  2.2,
#  20.0,
#  1.0,
#  2.85,
#  1.9,
#  3.1,
#  2.1,
#  2.4,
#  2.4,
#  0.8]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# It seems that £20.00 probably has the decimal in the wrong place. £2.00 seems a much more sensible price for coffee. This is an example of a fairly common error, particualrly if the data has been entered by a human.
# ### We have identified the first bit of data that needs cleaning!
# There are several ways we can do this

# %% [markdown]
# 1) Re-wrtie the list using <code>[]</code> with each variable seperated by a comma.
#     We are going to assign the cleaned coffee variables to a new column called 'price_clean1' so we can compare columns later.
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
# rewrite the coffee as a list with the correct value in place
# and use = to asign this to coffee['price_clean1']
coffee['price_clean1']= [2.4, 2.6, 2.5, 2.0, 2.5, 2.7, 2.75, 3.0, 2.9, 1.8, 3.0, 2.5, 3.0, 2.7, 2.2, 2.0, 1.0, 2.85, 1.9, 3.1, 2.1, 2.4, 2.4, 0.8]
# print to check
print(coffee['price_clean1'])
# Out:
# 0     2.40
# 1     2.60
# 2     2.50
# 3     2.00
# 4     2.50
# 5     2.70
# 6     2.75
# 7     3.00
# 8     2.90
# 9     1.80
# 10    3.00
# 11    2.50
# 12    3.00
# 13    2.70
# 14    2.20
# 15    2.00
# 16    1.00
# 17    2.85
# 18    1.90
# 19    3.10
# 20    2.10
# 21    2.40
# 22    2.40
# 23    0.80
# Name: price_clean1, dtype: float64

# %%
# create another 2 duplicates of column price and name them price_clean2, price_clean3 
# we will use them later on
coffee['price_clean2'] = coffee['price'] 
coffee['price_clean3'] = coffee['price'] 
# printing the columns shows they are duplicates of the original 'price' column
print(coffee['price_clean2'],coffee['price_clean3'])
# Out:
# 0      2.40
# 1      2.60
# 2      2.50
# 3      2.00
# 4      2.50
# 5      2.70
# 6      2.75
# 7      3.00
# 8      2.90
# 9      1.80
# 10     3.00
# 11     2.50
# 12     3.00
# 13     2.70
# 14     2.20
# 15    20.00
# 16     1.00
# 17     2.85
# 18     1.90
# 19     3.10
# 20     2.10
# 21     2.40
# 22     2.40
# 23     0.80
# Name: price_clean2, dtype: float64 0      2.40
# 1      2.60
# 2      2.50
# 3      2.00
# 4      2.50
# 5      2.70
# 6      2.75
# 7      3.00
# 8      2.90
# 9      1.80
# 10     3.00
# 11     2.50
# 12     3.00
# 13     2.70
# 14     2.20
# 15    20.00
# 16     1.00
# 17     2.85
# 18     1.90
# 19     3.10
# 20     2.10
# 21     2.40
# 22     2.40
# 23     0.80
# Name: price_clean3, dtype: float64

# %% [markdown]
# Typing out the whole list of coffee prices is quite time consuming, we wouldn't be able to do it if we had 100s of rows of data.
# Instead we can identify which row the incorrect value is in and correct just that value.

# %%
print(coffee['price'])
# Out:
# 0      2.40
# 1      2.60
# 2      2.50
# 3      2.00
# 4      2.50
# 5      2.70
# 6      2.75
# 7      3.00
# 8      2.90
# 9      1.80
# 10     3.00
# 11     2.50
# 12     3.00
# 13     2.70
# 14     2.20
# 15    20.00
# 16     1.00
# 17     2.85
# 18     1.90
# 19     3.10
# 20     2.10
# 21     2.40
# 22     2.40
# 23     0.80
# Name: price, dtype: float64

# %% [markdown]
# We can see that the £20.00 coffee is in row 15. Note that the row indexing starts at zero (not one) in Python.
#
# We can use the <code><font color='blue'>dataframe_name</font>.loc</code> attribute of pandas dataframes to access rows and/or columns of the dataframe we want to edit.
#
# The general format of loc is shown by the code bellow. The first item in the squared brackets identifies the row(s) of interest and the second item (after the comma) identifies the column(s) of interest
# <code><font color='blue'>dataframe_name</font>.loc[<font color='blue'>row label</font>,<font color='blue'>column_lable</font>]</code>
#
# NOTE: to select all rows or all columns use a colon <code>:</code>
#
# <br><font color='orchid'><b> Run through the next few cells and make sure you understand how <code>.loc</code> is working to select the different columns and rows </b></font>

# %%
# select all rows and column price_clean2
coffee.loc[:,"price_clean2"]
# Out:
# 0      2.40
# 1      2.60
# 2      2.50
# 3      2.00
# 4      2.50
# 5      2.70
# 6      2.75
# 7      3.00
# 8      2.90
# 9      1.80
# 10     3.00
# 11     2.50
# 12     3.00
# 13     2.70
# 14     2.20
# 15    20.00
# 16     1.00
# 17     2.85
# 18     1.90
# 19     3.10
# 20     2.10
# 21     2.40
# 22     2.40
# 23     0.80
# Name: price_clean2, dtype: float64

# %%
# select row 5 and all columns
coffee.iloc[[5],:]
# Out:
#        coffee_name coffee_type coffee_shop  price  cake_deal  rating  \
# 5  nero_puppuccino  puppuccino        nero    2.7      False       1
#
#    price_clean1  price_clean2  price_clean3
# 5           2.7           2.7           2.7

# %%
# select row 3-7 and columns 'price' and 'rating'
coffee.loc[[3,4,5,6,7],['price','rating']]
# Out:
#    price  rating
# 3   2.00       4
# 4   2.50       4
# 5   2.70       1
# 6   2.75       3
# 7   3.00       4

# %%
# using iloc we can use the index of the columns as well.
# select rows 0-3 and columns 0-4
coffee.iloc[[0,1,2,3],[0,1,2,3,4]]
# Out:
#       coffee_name coffee_type coffee_shop  price  cake_deal
# 0  nero_americano   americano        nero    2.4       True
# 1      nero_mocha       mocha        nero    2.6      False
# 2      nero_latte       latte        nero    2.5      False
# 3  nero_espresso    espresso         nero    2.0       True

# %%
# check the location of the incorrect data is row 15 in column price_clean2
coffee.loc[[15],"price_clean2"]
# Out:
# 15    20.0
# Name: price_clean2, dtype: float64

# %%
# assign the incorrect data the correct value
coffee.loc[[15],"price_clean2"] =2.0
print(coffee['price_clean2'])
# Out:
# 0     2.40
# 1     2.60
# 2     2.50
# 3     2.00
# 4     2.50
# 5     2.70
# 6     2.75
# 7     3.00
# 8     2.90
# 9     1.80
# 10    3.00
# 11    2.50
# 12    3.00
# 13    2.70
# 14    2.20
# 15    2.00
# 16    1.00
# 17    2.85
# 18    1.90
# 19    3.10
# 20    2.10
# 21    2.40
# 22    2.40
# 23    0.80
# Name: price_clean2, dtype: float64

# %% [markdown]
# The above two methods are great if only a few values need cleaning or the dataset is small enough to easily find the location of the incorrect data.
# However for large datasets these methods are impracticle and applying a more general rule would be better.
#
# We can hypothesis that any coffee over about £8 probably has had the price incorrectly entered and that the decimal point should be moved. Therefore we can find every row where the price is over £8 and divide it by 10 (effectively moving the decimal place back a digit).
#
#
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %% [markdown]
# Locate where coffee price is greater than or equal to £8: <code>coffee.loc[coffee['price']>=8] </code>

# %%
# is coffee price greater than or equal to £8.
# gives a boolean (true/false) answer
coffee['price']>=8
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# Name: price, dtype: bool

# %%
# use .loc to identify the row where coffee price is >= £8
coffee.loc[coffee['price']>=8]
# Out:
#              coffee_name coffee_type coffee_shop  price  cake_deal  rating  \
# 15  starbucks_cappuccino  cappuccino   starbucks   20.0      False       4
#
#     price_clean1  price_clean2  price_clean3
# 15           2.0           2.0          20.0

# %% [markdown]
# #### Now back to the cleaning
# <font color='orchid'> <b>Run the code bellow, using the comments to work out what each bit of the code is doing, ask if you have any questions </b></font>

# %%
# in rows where coffee price is >= £8,
# in column 'price_clean3' calculate the cleaned price of coffee
# by dividing the original coffee['price'] by 10

coffee.loc[coffee['price']>=8, 'price_clean3'] = coffee['price']/10
# view column price_clean3
print(coffee['price_clean3'])
# Out:
# 0     2.40
# 1     2.60
# 2     2.50
# 3     2.00
# 4     2.50
# 5     2.70
# 6     2.75
# 7     3.00
# 8     2.90
# 9     1.80
# 10    3.00
# 11    2.50
# 12    3.00
# 13    2.70
# 14    2.20
# 15    2.00
# 16    1.00
# 17    2.85
# 18    1.90
# 19    3.10
# 20    2.10
# 21    2.40
# 22    2.40
# 23    0.80
# Name: price_clean3, dtype: float64

# %% [markdown]
# ### Let's check our cleaning
# Lets check and compare our cleaning methods
# We can see the original price of £20.00 and then how each method has cleaned the data to £2.00
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
# show row 15 of the datrframe and the price columns 
coffee.loc[[15],['price','price_clean1','price_clean2','price_clean3']]
# Out:
#     price  price_clean1  price_clean2  price_clean3
# 15   20.0           2.0           2.0           2.0

# %% [markdown]
# # Visualising data
# ### <i> Often the best way to understand the data you have is to visualise it </i>

# %% [markdown]
# ### Histograms

# %% [markdown]
# We will plot two histograms to see the distribution of data before and after cleaning.
# <br>The simplest way to do this is using the matplotlib <code>.hist()</code> function.
# <br> <font color='orchid'> <b>Run the two cells below</b></font>

# %%
coffee['price'].hist();

# %%
coffee['price_clean1'].hist();

# %% [markdown]
# ### Scatterplots and correlations

# %% [markdown]
# Use the matplotlib pyplot <code>.scatter()</code> function to create a scatter plot.
# <br>Whilst a histogram is 1 dimensonal (takes one setof data), scatter plots plot two lots of data (often columns) against each other.
#
# We will use the scatter plot to see if there is a correlation between price and rating, specifying price as the x-axis variable and rating as the y-axis variable
# <br> <font color='orchid'> <b>Run the code below</b></font>

# %%
coffee.plot.scatter(x='price_clean3',y='rating');

# %% [markdown]
# ### A quick note on graph customisation
#
# There are lots of different ways to edit graphs to get them looking how you want
#
# - <code>s=</code>: scalar i.e. point size
# - <code>c=</code>: colour of the points, see the list of matplotlib colours below. colours need to be in speech marks e.g.<code>"red"</code>
# <img src= "Intro_to_Python\colours.png" width =600 >
# - <code>alpha=</code>: How transparent the point is, 0-1 (completely transparent- solid colour)
# - <code>marker=</code>: Defines how the point looks, there are a few examples below and more [here](https://matplotlib.org/3.1.1/api/markers_api.html#module-matplotlib.markers)
# <img src= "Intro_to_Python\marker.png" width =500 >
#
# <br> <font color='orchid'> <b>Play arround with the code below, changing different elements</b></font>

# %%
coffee.plot.scatter(x='price_clean3',y='rating', s=20, c='green', alpha=0.3);

# %% [markdown]
# <br> <font color='orchid'> <b>Plot your own scatter plot of price against rating with pink triangular points, scalar = 75 and make the points semi-transparent</b></font>

# %% [markdown]
# ### Visulisations using Seaborn
# The seaborn package can also be used to visulise data. Often producing cleaner and clearer looking plots along with statisitical graphics. <br>
#
# <code>sns.jointplot()</code> is used to plot two variable with seaborn. Notice it also prduces a histogram of the variable distibutions of each axis.
#
# Like with matplotlib elements of the graph are editable
#
# <code>kind=</code> : Can be “scatter” | “reg” | “resid” | “kde” | “hex”
# <br><font color= "orchid"><b> Run the code bellow and then try changing the kind of graph plotted </font>

# %%
sns.jointplot(x='price_clean3',y='rating', kind ='scatter',data=coffee);

# %%
# plot a kde plot

# %%
# plot a reg plot

# %%
# plot a hex plot

# %%
# plot a residuals plot
# these are used in statistical testing don't worry if you don't recongise then (we are not covering stats. theory here)

# %% [markdown]
# ### Different editable parameters with Seaborn
# To edit the seaborn plot, the parameters you specify are slightly different to matplotlib.
#
# You will notice with seaborn that the <code>x</code> and <code>y</code> specify only the column name and <code>data</code> is used to specify the dataframe where the <code>x</code>&<code>y</code> columns can be found.
#
# #### Other editable parameters:
# - <code>color=</code> colour of the points, see the list of matplotlib colours. Colours need to be in speech marks e.g.<code>"red"</code>
# <br>Note the American spelling, using 'colour' will produce an error
# - <code>height=</code> Size of the figure (it will be square), enter a numerical value.
# - <code>marker=</code> Same as matplotlib
#
# Read more about the editable parameters in the [seaborn jointplot documentation](https://seaborn.pydata.org/generated/seaborn.jointplot.html)
# <br> <font color='orchid'> <b>Play arround with the code below, changing different elements</b></font>

# %%
sns.jointplot(x='price_clean3',y='rating', kind ='scatter',data=coffee,\
             color='grey', height=8, marker='v');

# %% [markdown]
# ## Plotting categorical data
# ### Bar chart
#
# We are going to use seaborne.catplot; this is a visulisation which can handle categorical data.
#
# We are going to plot the column 'coffee_shop;, as each row is a unique type of coffee by counting the number of times the coffee shop name occurs that tells us how many coffees they sell.

# %%
sns.catplot(x='coffee_shop', data=coffee, kind='count');

# %% [markdown]
# ### Now produce a count plot for column 'coffee_type'
# <font color='orchid'> <b>Write your own code in the cell bellow</b></font>

# %% [markdown]
# This is what you should see ![image.png](attachment:image.png)

# %% [markdown]
# ### Box plot
#
# Visualises the summary statisitcs of the data: mean/median and interquartile ranges

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x='coffee_type', y='rating', data=coffee);

# %% [markdown]
# ### Violin plot
# Also visualises the summary statisitcs of the data, but often prefered over a box plot as they also show the distribution of the data

# %%
plt.figure(figsize=(10,5))
sns.violinplot(x='coffee_type', y='rating', data=coffee);

# %% [markdown]
# You can edit the violin plot to show a third variable, using the <code>hue</code> parameter.
# <br>Adding <code>hue='cake_deal'</code> will produce a violinplot for every coffee type with and without a cake deal

# %%
# Visualise the diistirbution and summary stats. of coffee price for each coffe type, with and without a cake deal.

# define plot size
plt.figure(figsize=(10,5))
# plot
sns.violinplot(x='coffee_type', y='price_clean1', hue='cake_deal', data=coffee);

# %% [markdown]
# ### Categorical plot: the realtionship between a categorical and numerical variable

# %% [markdown]
# <font color='orchid'> <b>Plot the rating of each coffee by shop</font>

# %%
sns.catplot(x='coffee_shop', y='rating', data=coffee, height=6, dodge=True);

# %% [markdown]
# <font color='orchid'> <b>Plot the price of each coffee by type and colour the points based on the shop they were purchased from</font>

# %%
sns.catplot(x='coffee_type', y='price_clean1', hue='coffee_shop', data=coffee, height=6);

# %% [markdown]
# <font color='orchid'> <b>Plot the cleaned price of each coffee by shop and colour the points based on the rating they were given </font>

# %% [markdown]
# It should look like this
# ![image.png](attachment:image.png)

# %% [markdown]
# We will cover more complex visualisations next week. But if you are interested try looking at the [seaborn example gallery](https://seaborn.pydata.org/examples/index.html) and experiment by plotting some of the visualisations with the coffee data. <br>
# You can also try reading in your own data (make sure its in a CSV format- this is easy to do [for excel spreadsheets](https://www.ablebits.com/office-addins-blog/2014/04/24/convert-excel-csv/)) using <code>pd.read_csv()</code> and making your own visualistaions.

# %% [markdown]
# <a id='file_paths'></a>
# # File Paths

# %% [markdown]
# A file path identifies the exact unique location of a file or folder in a file system.
# <br>E.g. I created this notebook in the following folders.<br>
# * F: (USB)
#     * 2019_20 (Folder)
#         * Data_Science (Folder)
#             * Intro_to_Python (Folder)
#                 * Intro_to_Python.ipyn (the Jupyter Notebook file)<br>
#
# ![image.png](attachment:image.png)
#
#
# Resulting in the file path:"F:\2019_20\Data_Science\Intro_to_Python\Intro to Python.ipynb"
